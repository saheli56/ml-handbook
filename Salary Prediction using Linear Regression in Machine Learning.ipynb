# %% [markdown]
# <a href="https://colab.research.google.com/github/saheli56/ml-handbook/blob/main/Salary%20Prediction%20using%20Linear%20Regression%20in%20Machine%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# . Speed - fast
#
# . Distance = more
# Speed        Distance
# 10             10
# 20             20
# 30             30

# %%
# y = mx+c
# y = b1x = b0

# %%
import pandas as pd

# %%
dataset = pd.read_csv("/content/Salary_Data.csv")
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
y = dataset["Salary"]
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
x = dataset["YearsExperience"]
plt.plot(x,y,'rx')

# %%
# train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30, random_state = 0)

# %%
x_train.shape
# Out:
# (21,)

# %%
x_test.shape
# Out:
# (9,)

# %%
#model
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(x_train.values.reshape(-1, 1),y_train)
# Out:
# LinearRegression()

# %%
# y = mx +c
print(linear_regressor.intercept_)
# Out:
# 26777.391341197625

# %%
print(linear_regressor.coef_)
# Out:
# [9360.26128619]

# %%
y_pred = linear_regressor.predict(x_test.values.reshape(-1, 1))
y_pred
# Out:
# array([ 40817.78327049, 123188.08258899,  65154.46261459,  63282.41035735,
#        115699.87356004, 108211.66453108, 116635.89968866,  64218.43648597,
#         76386.77615802])

# %%
y_test
# Out:
# 2      37731.0
# 28    122391.0
# 13     57081.0
# 10     63218.0
# 26    116969.0
# 24    109431.0
# 27    112635.0
# 11     55794.0
# 17     83088.0
# Name: Salary, dtype: float64

# %%
plt.plot(x_test,y_test,'rx')
plt.plot(x_test,y_pred,c='black')

# %%
# evaluate

from sklearn import metrics
print(metrics.mean_absolute_error(y_test,y_pred))
# Out:
# 3737.417861878896

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
# Out:
# 23370078.800832972
