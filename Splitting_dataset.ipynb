# %% [markdown]
# <a href="https://colab.research.google.com/github/saheli56/ml-handbook/blob/main/Splitting_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/IRIS.csv',header=None,names=['sl','sw','pl','pw','lables'])

# %%
data
# Out:
#                sl           sw            pl           pw          lables
# 0    sepal_length  sepal_width  petal_length  petal_width         species
# 1             5.1          3.5           1.4          0.2     Iris-setosa
# 2             4.9            3           1.4          0.2     Iris-setosa
# 3             4.7          3.2           1.3          0.2     Iris-setosa
# 4             4.6          3.1           1.5          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.7            3           5.2          2.3  Iris-virginica
# 147           6.3          2.5             5          1.9  Iris-virginica
# 148           6.5            3           5.2            2  Iris-virginica
# 149           6.2          3.4           5.4          2.3  Iris-virginica
# 150           5.9            3           5.1          1.8  Iris-virginica
#
# [151 rows x 5 columns]

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                sl           sw            pl           pw          lables
# 0    sepal_length  sepal_width  petal_length  petal_width         species
# 1             5.1          3.5           1.4          0.2     Iris-setosa
# 2             4.9            3           1.4          0.2     Iris-setosa
# 3             4.7          3.2           1.3          0.2     Iris-setosa
# 4             4.6          3.1           1.5          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.7            3           5.2          2.3  Iris-virginica
# 147           6.3          2.5             5          1.9  Iris-virginica
# 148           6.5            3           5.2            2  Iris-virginica
# 149           6.2          3.4           5.4          2.3  Iris-virginica
# 150           5.9            3           5.1          1.8  Iris-virginica
#
# [151 rows x 5 columns]

# %%
# manual
# i/p = x
# o/p = y

# %%
x = data.iloc[:,:4]

# %%
x
# Out:
#                sl           sw            pl           pw
# 0    sepal_length  sepal_width  petal_length  petal_width
# 1             5.1          3.5           1.4          0.2
# 2             4.9            3           1.4          0.2
# 3             4.7          3.2           1.3          0.2
# 4             4.6          3.1           1.5          0.2
# ..            ...          ...           ...          ...
# 146           6.7            3           5.2          2.3
# 147           6.3          2.5             5          1.9
# 148           6.5            3           5.2            2
# 149           6.2          3.4           5.4          2.3
# 150           5.9            3           5.1          1.8
#
# [151 rows x 4 columns]

# %%
y = data.iloc[:,:4]

# %%
y
# Out:
#                sl           sw            pl           pw
# 0    sepal_length  sepal_width  petal_length  petal_width
# 1             5.1          3.5           1.4          0.2
# 2             4.9            3           1.4          0.2
# 3             4.7          3.2           1.3          0.2
# 4             4.6          3.1           1.5          0.2
# ..            ...          ...           ...          ...
# 146           6.7            3           5.2          2.3
# 147           6.3          2.5             5          1.9
# 148           6.5            3           5.2            2
# 149           6.2          3.4           5.4          2.3
# 150           5.9            3           5.1          1.8
#
# [151 rows x 4 columns]

# %%
# Training and Testing

# %%
x_train = x.iloc[:100]

# %%
x_test = x.iloc[100:]

# %%
x_train
# Out:
#               sl           sw            pl           pw
# 0   sepal_length  sepal_width  petal_length  petal_width
# 1            5.1          3.5           1.4          0.2
# 2            4.9            3           1.4          0.2
# 3            4.7          3.2           1.3          0.2
# 4            4.6          3.1           1.5          0.2
# ..           ...          ...           ...          ...
# 95           5.6          2.7           4.2          1.3
# 96           5.7            3           4.2          1.2
# 97           5.7          2.9           4.2          1.3
# 98           6.2          2.9           4.3          1.3
# 99           5.1          2.5             3          1.1
#
# [100 rows x 4 columns]

# %%
x_test
# Out:
#       sl   sw   pl   pw
# 100  5.7  2.8  4.1  1.3
# 101  6.3  3.3    6  2.5
# 102  5.8  2.7  5.1  1.9
# 103  7.1    3  5.9  2.1
# 104  6.3  2.9  5.6  1.8
# 105  6.5    3  5.8  2.2
# 106  7.6    3  6.6  2.1
# 107  4.9  2.5  4.5  1.7
# 108  7.3  2.9  6.3  1.8
# 109  6.7  2.5  5.8  1.8
# 110  7.2  3.6  6.1  2.5
# 111  6.5  3.2  5.1    2
# 112  6.4  2.7  5.3  1.9
# 113  6.8    3  5.5  2.1
# 114  5.7  2.5    5    2
# 115  5.8  2.8  5.1  2.4
# 116  6.4  3.2  5.3  2.3
# 117  6.5    3  5.5  1.8
# 118  7.7  3.8  6.7  2.2
# 119  7.7  2.6  6.9  2.3
# 120    6  2.2    5  1.5
# 121  6.9  3.2  5.7  2.3
# 122  5.6  2.8  4.9    2
# 123  7.7  2.8  6.7    2
# 124  6.3  2.7  4.9  1.8
# 125  6.7  3.3  5.7  2.1
# 126  7.2  3.2    6  1.8
# 127  6.2  2.8  4.8  1.8
# 128  6.1    3  4.9  1.8
# 129  6.4  2.8  5.6  2.1
# 130  7.2    3  5.8  1.6
# 131  7.4  2.8  6.1  1.9
# 132  7.9  3.8  6.4    2
# 133  6.4  2.8  5.6  2.2
# 134  6.3  2.8  5.1  1.5
# 135  6.1  2.6  5.6  1.4
# 136  7.7    3  6.1  2.3
# ...

# %%
y_train = y.iloc[:100]

# %%
y_test = y.iloc[100:]

# %%
y_train
# Out:
#               sl           sw            pl           pw
# 0   sepal_length  sepal_width  petal_length  petal_width
# 1            5.1          3.5           1.4          0.2
# 2            4.9            3           1.4          0.2
# 3            4.7          3.2           1.3          0.2
# 4            4.6          3.1           1.5          0.2
# ..           ...          ...           ...          ...
# 95           5.6          2.7           4.2          1.3
# 96           5.7            3           4.2          1.2
# 97           5.7          2.9           4.2          1.3
# 98           6.2          2.9           4.3          1.3
# 99           5.1          2.5             3          1.1
#
# [100 rows x 4 columns]

# %%
y_test
# Out:
#       sl   sw   pl   pw
# 100  5.7  2.8  4.1  1.3
# 101  6.3  3.3    6  2.5
# 102  5.8  2.7  5.1  1.9
# 103  7.1    3  5.9  2.1
# 104  6.3  2.9  5.6  1.8
# 105  6.5    3  5.8  2.2
# 106  7.6    3  6.6  2.1
# 107  4.9  2.5  4.5  1.7
# 108  7.3  2.9  6.3  1.8
# 109  6.7  2.5  5.8  1.8
# 110  7.2  3.6  6.1  2.5
# 111  6.5  3.2  5.1    2
# 112  6.4  2.7  5.3  1.9
# 113  6.8    3  5.5  2.1
# 114  5.7  2.5    5    2
# 115  5.8  2.8  5.1  2.4
# 116  6.4  3.2  5.3  2.3
# 117  6.5    3  5.5  1.8
# 118  7.7  3.8  6.7  2.2
# 119  7.7  2.6  6.9  2.3
# 120    6  2.2    5  1.5
# 121  6.9  3.2  5.7  2.3
# 122  5.6  2.8  4.9    2
# 123  7.7  2.8  6.7    2
# 124  6.3  2.7  4.9  1.8
# 125  6.7  3.3  5.7  2.1
# 126  7.2  3.2    6  1.8
# 127  6.2  2.8  4.8  1.8
# 128  6.1    3  4.9  1.8
# 129  6.4  2.8  5.6  2.1
# 130  7.2    3  5.8  1.6
# 131  7.4  2.8  6.1  1.9
# 132  7.9  3.8  6.4    2
# 133  6.4  2.8  5.6  2.2
# 134  6.3  2.8  5.1  1.5
# 135  6.1  2.6  5.6  1.4
# 136  7.7    3  6.1  2.3
# ...

# %%
#2nd
# sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=30, random_state =1)

# %%
x_train
# Out:
#       sl   sw   pl   pw
# 91   5.5  2.6  4.4  1.2
# 135  6.1  2.6  5.6  1.4
# 69   6.2  2.2  4.5  1.5
# 128  6.1    3  4.9  1.8
# 114  5.7  2.5    5    2
# ..   ...  ...  ...  ...
# 133  6.4  2.8  5.6  2.2
# 137  6.3  3.4  5.6  2.4
# 72   6.1  2.8    4  1.3
# 140  6.9  3.1  5.4  2.1
# 37   5.5  3.5  1.3  0.2
#
# [121 rows x 4 columns]

# %%
x_test
# Out:
#       sl   sw   pl   pw
# 14   4.3    3  1.1  0.1
# 98   6.2  2.9  4.3  1.3
# 75   6.4  2.9  4.3  1.3
# 16   5.7  4.4  1.5  0.4
# 131  7.4  2.8  6.1  1.9
# 56   5.7  2.8  4.5  1.3
# 141  6.7  3.1  5.6  2.4
# 44     5  3.5  1.6  0.6
# 29   5.2  3.4  1.4  0.2
# 120    6  2.2    5  1.5
# 94     5  2.3  3.3    1
# 5      5  3.6  1.4  0.2
# 102  5.8  2.7  5.1  1.9
# 51     7  3.2  4.7  1.4
# 78   6.7    3    5  1.7
# 42   4.5  2.3  1.3  0.3
# 92   6.1    3  4.6  1.4
# 66   6.7  3.1  4.4  1.4
# 31   4.8  3.1  1.6  0.2
# 35   4.9  3.1  1.5  0.1
# 90   5.5  2.5    4  1.3
# 84     6  2.7  5.1  1.6
# 77   6.8  2.8  4.8  1.4
# 40   5.1  3.4  1.5  0.2
# 125  6.7  3.3  5.7  2.1
# 99   5.1  2.5    3  1.1
# 33   5.2  4.1  1.5  0.1
# 19   5.7  3.8  1.7  0.3
# 73   6.3  2.5  4.9  1.5
# 147  6.3  2.5    5  1.9

# %%
y_train
# Out:
#       sl   sw   pl   pw
# 91   5.5  2.6  4.4  1.2
# 135  6.1  2.6  5.6  1.4
# 69   6.2  2.2  4.5  1.5
# 128  6.1    3  4.9  1.8
# 114  5.7  2.5    5    2
# ..   ...  ...  ...  ...
# 133  6.4  2.8  5.6  2.2
# 137  6.3  3.4  5.6  2.4
# 72   6.1  2.8    4  1.3
# 140  6.9  3.1  5.4  2.1
# 37   5.5  3.5  1.3  0.2
#
# [121 rows x 4 columns]

# %%
y_test
# Out:
#       sl   sw   pl   pw
# 14   4.3    3  1.1  0.1
# 98   6.2  2.9  4.3  1.3
# 75   6.4  2.9  4.3  1.3
# 16   5.7  4.4  1.5  0.4
# 131  7.4  2.8  6.1  1.9
# 56   5.7  2.8  4.5  1.3
# 141  6.7  3.1  5.6  2.4
# 44     5  3.5  1.6  0.6
# 29   5.2  3.4  1.4  0.2
# 120    6  2.2    5  1.5
# 94     5  2.3  3.3    1
# 5      5  3.6  1.4  0.2
# 102  5.8  2.7  5.1  1.9
# 51     7  3.2  4.7  1.4
# 78   6.7    3    5  1.7
# 42   4.5  2.3  1.3  0.3
# 92   6.1    3  4.6  1.4
# 66   6.7  3.1  4.4  1.4
# 31   4.8  3.1  1.6  0.2
# 35   4.9  3.1  1.5  0.1
# 90   5.5  2.5    4  1.3
# 84     6  2.7  5.1  1.6
# 77   6.8  2.8  4.8  1.4
# 40   5.1  3.4  1.5  0.2
# 125  6.7  3.3  5.7  2.1
# 99   5.1  2.5    3  1.1
# 33   5.2  4.1  1.5  0.1
# 19   5.7  3.8  1.7  0.3
# 73   6.3  2.5  4.9  1.5
# 147  6.3  2.5    5  1.9
